# %%
# Importando bibliotecas necessárias:
import matplotlib
from matplotlib import pyplot as plt

# %matplotlib inline
#%matplotlib

# %%
# Definindo as cores 
GRAY1, GRAY2, GRAY3 = '#231F20', '#414040', '#555655'
GRAY4, GRAY5, GRAY6 = '#646369', '#76787B', '#828282'
GRAY7, GRAY8, GRAY9 = '#929497', '#A6A6A5', '#BFBEBE'
BLUE1, BLUE2, BLUE3, BLUE4 = '#174A7E', '#4A81BF', '#94B2D7', '#94AFC5'
RED1, RED2 = '#C3514E', '#E6BAB7'
GREEN1, GREEN2 = '#0C8040', '#9ABB59'
ORANGE1 = '#F79747'

# %%
# Fontes para Arial
plt.rcParams['font.family'] = 'Arial'
matplotlib.rcParams['mathtext.fontset'] = 'custom'
matplotlib.rcParams['mathtext.bf'] = 'Arial:bold'
matplotlib.rcParams['mathtext.it'] = 'Arial:italic'

# %%
# Criando uma nova figura
plt.figure(figsize=(7.45, 4.9), dpi=110)             

# Removendo bordas 
for spine in plt.gca().spines.values():
    spine.set_visible(False)

# Trocando aparência dos ticks
plt.tick_params(bottom='off', left='off', labelleft='off', labelbottom='off')

# Título para o gráfico
plt.text(-0.15, 1.03,
         'A brincadeira foi um sucesso, sqn'+' '*27,
         fontsize=26,
         color='white',
         # Box retangular
         bbox={'facecolor': GRAY7, 'pad': 10, 'edgecolor': BLUE2})

# Fonte do gráfico
plt.text(-0.15, 0.04,
         'Mesmo assim, é melhor do que nada \n'
         'De pouco em pouco é que se aprende \n'
         '=D',
         fontsize=10.5,
         color=GRAY3)

# Nota 1
plt.text(-0.15, 0.81,
         'Depois do estudo,',
         fontsize=19,
         color=BLUE2)

# Nota 2
plt.text(-0.15, 0.41,
         '$\\bf{1\%}$', # use mathtext \\bf for bold text
         fontsize=122,
         color=BLUE2)

# Nota 3
plt.text(-0.15, 0.25,
         # use mathtext \\bf for bold text
         '$\\bf{foi \ o \ conhecimento \ absorvido \ por \ Gustavo}$',
         fontsize=19,
         color=BLUE2)

# Nota 4
plt.text(-0.15, 0.17,
         'comparado com antes do treino.',
         fontsize=19,
         color=GRAY7)
# Out:
# Text(-0.15, 0.17, 'comparado com antes do treino.')
